# %% [markdown]
# # Laporan Praktikum Big Data Pertemuan-1
# # Pengenalan Big Data dan Overview Teknologi

# %% [markdown]
# Big Data merupakan kumpulan data yang sangat besar, kompleks, dan terus bertambah seiring berjalannya waktu. Data - data tersebut dihasilkan dari aktivitas internet yang sering dilakukan oleh pengguna untuk keperluan pribadi atau bisnis. Untuk itu, pada praktikum kali ini akan dibahas mengenai konsep dasar Big Data, karakteristik dan tantangan Big Data, teknologi yang akan digunakan dalam ekosistem Big Data, menginstal dan mengkonfigurasikan anaconda, dan memulai praktik sederhana untuk pengolahan data menggunakan PySpark dan Pandas. Adapun alat-alat yang diperlukan adalah Anaconda, Jupyter Notebook, PySpark, Pandas, dan Python.

# %% [markdown]
# ### Langkah-langkah Hands-On

# %% [markdown]
# #### 1. Instalasi Anaconda

# %% [markdown]
# - Unduh dan Instal Anaconda pada website resmi, kemudian ikuti langkah-langkah instalasi sesuai sistem operasi. Setelah berhasil terinstal, akan muncul tampilan seperti di bawah ini.
#
# ![image.png](attachment:2823696a-b2dc-4174-a096-a8f2e9b2400b.png)

# %% [markdown]
# - Setelah itu buka Anaconda, pilih menu Environments, lalu buat environtment baru seperti gambar dibawah ini :
#
# ![image.png](attachment:28a7d154-0ae1-4ca2-afbe-bc9ec053ef3e.png)

# %% [markdown]
# - Setelah menekan tombol create, maka Environments baru berhasil dibuat dan akan muncul seperti gambar dibawah ini :
#
# ![image.png](attachment:8258e8e1-b55e-4172-974f-77ff04acd4c5.png)

# %% [markdown]
# - Untuk menggunakan Environments tersebut, tekan pada nama Environtments. Setelah itu kembali ke menu Home dan cek nama channels sudah sesuai atau belum. Kemudian install Jupyter Notebook.
#
# ![image.png](attachment:88d62649-34d1-4f10-af0f-355c30490705.png)

# %% [markdown]
# - Setelah itu, launch Jupyter Notebook dan buka file Hands_On_Pertemuan_1.ipynb seperti gambar dibawah ini :
#
# ![image.png](attachment:66848063-9dd5-450c-b8ad-4de3ee6b3728.png)

# %% [markdown]
# - Setelah itu kembali ke Anaconda dan masuk ke bagian Environments. Tekan tombol segitiga warna hijau, kemudian tekan Open Terminal untuk menginstal pyspark, pandas, findspark, dan matplotlib. Dengan mengetikkan perintah sebagai berikut :
#
# ![image.png](attachment:c461fbb6-698a-46c5-9027-443388959002.png)
# ![image.png](attachment:49238dea-bbe9-4855-97dc-430dc57fa5cb.png)
# ![image.png](attachment:30ca99c0-11a0-40d5-bb08-34c9bd946831.png)
# ![image.png](attachment:7666a82b-6bc6-458f-94ab-a93655603618.png)

# %% [markdown]
# - Setelah itu kembali ke Environments untuk menginstal openjdk dengan cara di cari menggunakan pencarian, kemudian centang openjdk, lalu apply.
#
# ![image.png](attachment:e85fdfc5-42fa-4a2b-b291-419f47a14e4d.png)

# %% [markdown]
# - Setelah itu, buka kembali file Hands On, restart kernel, lalu run satu per satu kode yang ada di dalam file Hands On.
#
# ![image.png](attachment:818913ab-2b42-4fe5-9278-4b7827aeccf3.png)

# %% [markdown]
# #### 2. Pengenalan dan Praktik Dasar PySpark dan Pandas

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34), ("Budi", 23), ("Citra", 29), ("Dina", 45)]
columns = ["Nama", "Usia"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+

# %% [markdown]
# #### 3. Praktik PySpark Lanjutan

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34), ("Budi", 23), ("Citra", 29), ("Dina", 45)]
columns = ["Nama", "Usia"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()

# Filtering data
df_filtered = df.filter(df['Usia'] > 30)
df_filtered.show()

# Menghitung rata-rata usia
from pyspark.sql.functions import avg
df.groupBy().agg(avg("Usia")).show()

# Mengurutkan data berdasarkan usia
df_sorted = df.orderBy("Usia", ascending=False)
df_sorted.show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+
#
# +----+----+
# |Nama|Usia|
# +----+----+
# | Ali|  34|
# |Dina|  45|
# +----+----+
#
# +---------+
# |avg(Usia)|
# +---------+
# |    32.75|
# +---------+
#
# +-----+----+
# | Nama|Usia|
# +-----+----+
# | Dina|  45|
# |  Ali|  34|
# |Citra|  29|
# | Budi|  23|
# +-----+----+

# %% [markdown]
# #### 4. Praktik dengan Pandas

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Usia": [34, 23, 29, 45]}
df_pandas = pd.DataFrame(data_pandas)

# Menampilkan DataFrame Pandas
df_pandas
# Out:
#     Nama  Usia
# 0    Ali    34
# 1   Budi    23
# 2  Citra    29
# 3   Dina    45

# %% [markdown]
# #### 5. Praktik Pandas Lanjutan

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Usia": [34, 23, 29, 45]}
df_pandas = pd.DataFrame(data_pandas)

# Membuat DataFrame kedua
data_pandas_2 = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Pekerjaan": ["Dokter", "Guru", "Insinyur", "Perawat"]}
df_pandas_2 = pd.DataFrame(data_pandas_2)

# Join antara dua DataFrame
df_joined = pd.merge(df_pandas, df_pandas_2, on="Nama")
print(df_joined)

# Menghitung statistik deskriptif
print(df_pandas.describe())

# Plotting Data
import matplotlib.pyplot as plt
df_pandas['Usia'].plot(kind='bar')
plt.show()
# Out:
#     Nama  Usia Pekerjaan
# 0    Ali    34    Dokter
# 1   Budi    23      Guru
# 2  Citra    29  Insinyur
# 3   Dina    45   Perawat
#             Usia
# count   4.000000
# mean   32.750000
# std     9.322911
# min    23.000000
# 25%    27.500000
# 50%    31.500000
# 75%    36.750000
# max    45.000000

# %% [markdown]
# #### 6. Menggabungkan PySpark dan Pandas

# %%
# Mengonversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konversi
df_pandas_from_spark, df_spark_from_pandas.show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+
# (    Nama  Usia
#  0    Ali    34
#  1   Budi    23
#  2  Citra    29
#  3   Dina    45,
#  None)

# %% [markdown]
# #### 7. Konversi Data antara PySpark dan Pandas

# %%
# Mengonversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konversi
df_pandas_from_spark, df_spark_from_pandas.show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+
# (    Nama  Usia
#  0    Ali    34
#  1   Budi    23
#  2  Citra    29
#  3   Dina    45,
#  None)

# %% [markdown]
# ### TUGAS

# %% [markdown]
# 1. Jalankan kode di atas dan buat modifikasi dengan menambahkan data lain berupa kolom pekerjaan, hobi dan gender.

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34, "Pilot", "Memanah", "L"), ("Budi", 23, "Nelayan", "Membaca", "L"), ("Citra", 29, "Guru", "Belanja", "P"), ("Dina", 45, "Petani", "Lari", "P")]
columns = ["Nama", "Usia", "Pekerjaan", "Hobi", "Gender"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFraame
df.show()
# Out:
# +-----+----+---------+-------+------+
# | Nama|Usia|Pekerjaan|   Hobi|Gender|
# +-----+----+---------+-------+------+
# |  Ali|  34|    Pilot|Memanah|     L|
# | Budi|  23|  Nelayan|Membaca|     L|
# |Citra|  29|     Guru|Belanja|     P|
# | Dina|  45|   Petani|   Lari|     P|
# +-----+----+---------+-------+------+

# %% [markdown]
# 2. Lakukan filter, penghitungan rata-rata, dan pengurutan data menggunakan PySpark.

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Abi", 4), ("Boni", 3), ("Chika", 9), ("Denis", 5)]
columns = ["Nama", "Usia"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()

# Filtering data
df_filtered = df.filter(df['Usia'] > 3)
df_filtered.show()

# Menghitung rata-rata usia
from pyspark.sql.functions import avg
df.groupBy().agg(avg("Usia")).show()

# Mengurutkan data berdasarkan usia
df_sorted = df.orderBy("Usia", ascending=False)
df_sorted.show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Abi|   4|
# | Boni|   3|
# |Chika|   9|
# |Denis|   5|
# +-----+----+
#
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Abi|   4|
# |Chika|   9|
# |Denis|   5|
# +-----+----+
#
# +---------+
# |avg(Usia)|
# +---------+
# |     5.25|
# +---------+
#
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |Chika|   9|
# |Denis|   5|
# |  Abi|   4|
# | Boni|   3|
# +-----+----+

# %% [markdown]
# 3. Modifikasi DataFrame Pandas dengan menambahkan kolom baru dan melakukan operasi seperti filtering data berdasarkan usia.

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Abi", "Boni", "Chika", "Denis"], "Usia": [4, 3, 9, 5], "Hobi": ["Memanjat", "Makan", "Bermain", "Bersepeda"]}
df_pandas = pd.DataFrame(data_pandas)

# Menampilkan DataFrame Pandas
df_pandas

#Mengurutkan data berdasarkan usia
df_sorted = df_pandas.sort_values("Usia")
df_sorted
# Out:
#     Nama  Usia       Hobi
# 1   Boni     3      Makan
# 0    Abi     4   Memanjat
# 3  Denis     5  Bersepeda
# 2  Chika     9    Bermain

# %% [markdown]
# 4. Lakukan penggabungan DataFrame dan visualisasikan data dengan Pandas.

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_1 = {"Nama": ["Abi", "Boni", "Chika", "Denis"], "Usia": [4, 3, 9, 5]}
df_pandas = pd.DataFrame(data_1)

# Membuat DataFrame kedua
data_2 = {"Nama": ["Abi", "Boni", "Chika", "Denis"], "Cita-cita": ["Dokter", "Guru", "Polwan", "Tentara"]}
df_pandas_2 = pd.DataFrame(data_2)

# Join antara dua DataFrame
df_joined = pd.merge(df_pandas, df_pandas_2, on="Nama")
print(df_joined)

# Plotting Data
import matplotlib.pyplot as plt
df_pandas['Usia'].plot(kind='bar')
plt.show()
# Out:
#     Nama  Usia Cita-cita
# 0    Abi     4    Dokter
# 1   Boni     3      Guru
# 2  Chika     9    Polwan
# 3  Denis     5   Tentara

# %% [markdown]
# 5. Gunakan metode ini untuk menggabungkan data yang Anda buat di PySpark dengan data dari Pandas, kemudian lakukan analisis sederhana seperti menghitung rata-rata usia.

# %%
# Mengonversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konversi
df_pandas_from_spark, df_spark_from_pandas.show()

#menghitung rata-rata usia
from pyspark.sql.functions import avg
df.groupBy().agg(avg("Usia")).show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Abi|   4|
# | Boni|   3|
# |Chika|   9|
# |Denis|   5|
# +-----+----+
#
# +---------+
# |avg(Usia)|
# +---------+
# |     5.25|
# +---------+

# %% [markdown]
# 6. Gabungkan data dari PySpark dan Pandas, lalu lakukan operasi statistik seperti menghitung nilai maksimum usia.

# %%
# Mengonversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konversi
df_pandas_from_spark, df_spark_from_pandas.show()

# Melakukan operasi statistik menghitung nilai maksimum usia
print(df_pandas.max())
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Abi|   4|
# | Boni|   3|
# |Chika|   9|
# |Denis|   5|
# +-----+----+
#
# Nama    Denis
# Usia        9
# dtype: object

# %% [markdown]
# ### Kesimpulan

# %% [markdown]
# Pada praktikum kali ini, telah dipahami konsep dasar Big Data dan alat - alat atau teknologi yang dapat digunakan untuk mengolah Big Data. Beberapa teknologi atau alat yang sudah dipelajari diantaranya adalah Anaconda, Jupyter Notebook, PySpark, Pandas, dan Python. Dengan adanya praktikum kali ini, dapat menambah pengetahuan mengenai pengolahan data menggunakan PySpark dan Pandas.
